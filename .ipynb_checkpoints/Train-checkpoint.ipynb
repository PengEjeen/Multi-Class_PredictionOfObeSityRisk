# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("./train.csv")
submit_x = pd.read_csv("./test.csv")

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  int64
#  1   Gender                          20758 non-null  object
#  2   Age                             20758 non-null  float64
#  3   Height                          20758 non-null  float64
#  4   Weight                          20758 non-null  float64
#  5   family_history_with_overweight  20758 non-null  object
#  6   FAVC                            20758 non-null  object
#  7   FCVC                            20758 non-null  float64
#  8   NCP                             20758 non-null  float64
#  9   CAEC                            20758 non-null  object
#  10  SMOKE                           20758 non-null  object
#  11  CH2O                            20758 non-null  float64
#  12  SCC                             20758 non-null  object
#  13  FAF                             20758 non-null  float64
#  14  TUE                             20758 non-null  float64
#  15  CALC                            20758 non-null  object
#  16  MTRANS                          20758 non-null  object
#  17  NObeyesdad                      20758 non-null  object
# dtypes: float64(8), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
Gender, family_history_with_overweight, FAVC, CAEC, SMOKE, SCC, CALC, MTRANS --> 범주형 변수 object
NObeyesdad --> target 범주형 변수 object
# Out:
#   Cell In[15], line 1
#     Gender, family_history_with_overweight, FAVC, CAEC, SMOKE, SCC, CALC, MTRANS --> 범주형 변수 object
#                                                                                   ^
# SyntaxError: invalid syntax

# %%
train_df.head(5)
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II

# %%
train_df.describe()
# Out:
#                 id           Age        Height        Weight          FCVC  \
# count  20758.00000  20758.000000  20758.000000  20758.000000  20758.000000
# mean   10378.50000     23.841804      1.700245     87.887768      2.445908
# std     5992.46278      5.688072      0.087312     26.379443      0.533218
# min        0.00000     14.000000      1.450000     39.000000      1.000000
# 25%     5189.25000     20.000000      1.631856     66.000000      2.000000
# 50%    10378.50000     22.815416      1.700000     84.064875      2.393837
# 75%    15567.75000     26.000000      1.762887    111.600553      3.000000
# max    20757.00000     61.000000      1.975663    165.057269      3.000000
#
#                 NCP          CH2O           FAF           TUE
# count  20758.000000  20758.000000  20758.000000  20758.000000
# mean       2.761332      2.029418      0.981747      0.616756
# std        0.705375      0.608467      0.838302      0.602113
# min        1.000000      1.000000      0.000000      0.000000
# 25%        3.000000      1.792022      0.008013      0.000000
# 50%        3.000000      2.000000      1.000000      0.573887
# 75%        3.000000      2.549617      1.587406      1.000000
# max        4.000000      3.000000      3.000000      2.000000

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/pengejeen/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/pengejeen/.local/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.8.3)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pengejeen/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/pengejeen/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
train_df.corr()
# Out:
# /tmp/ipykernel_5278/1233823885.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_df.corr()
#               id       Age    Height    Weight      FCVC       NCP      CH2O  \
# id      1.000000  0.007634  0.012041  0.014020  0.002098 -0.000332  0.007917
# Age     0.007634  1.000000 -0.011713  0.283381  0.034414 -0.048479 -0.016325
# Height  0.012041 -0.011713  1.000000  0.416677 -0.071546  0.191383  0.183706
# Weight  0.014020  0.283381  0.416677  1.000000  0.245682  0.095947  0.317914
# FCVC    0.002098  0.034414 -0.071546  0.245682  1.000000  0.113349  0.101299
# NCP    -0.000332 -0.048479  0.191383  0.095947  0.113349  1.000000  0.080949
# CH2O    0.007917 -0.016325  0.183706  0.317914  0.101299  0.080949  1.000000
# FAF     0.016719 -0.192259  0.295278 -0.084845 -0.089822  0.100871  0.082932
# TUE     0.007667 -0.296154  0.076433 -0.086471 -0.147843  0.067459 -0.010654
#
#              FAF       TUE
# id      0.016719  0.007667
# Age    -0.192259 -0.296154
# Height  0.295278  0.076433
# Weight -0.084845 -0.086471
# FCVC   -0.089822 -0.147843
# NCP     0.100871  0.067459
# CH2O    0.082932 -0.010654
# FAF     1.000000  0.021213
# TUE     0.021213  1.000000

# %%
df_copy = train_df.copy()

train_x = train_df.drop(labels="NObeyesdad",axis=1)
train_y = train_df["NObeyesdad"]

# %%
#Gender, family_history_with_overweight, FAVC, CAEC, SMOKE, SCC, CALC, MTRANS
#매핑 필요 or LabelEncoder
from sklearn.preprocessing import LabelEncoder

convert_list = ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS']

for column in convert_list:
    le = LabelEncoder()
    train_x[column] = le.fit_transform(train_x[column])
    submit_x[column] = le.fit_transform(submit_x[column])

print(train_x.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  int64
#  1   Gender                          20758 non-null  int64
#  2   Age                             20758 non-null  float64
#  3   Height                          20758 non-null  float64
#  4   Weight                          20758 non-null  float64
#  5   family_history_with_overweight  20758 non-null  int64
#  6   FAVC                            20758 non-null  int64
#  7   FCVC                            20758 non-null  float64
#  8   NCP                             20758 non-null  float64
#  9   CAEC                            20758 non-null  int64
#  10  SMOKE                           20758 non-null  int64
#  11  CH2O                            20758 non-null  float64
#  12  SCC                             20758 non-null  int64
#  13  FAF                             20758 non-null  float64
#  14  TUE                             20758 non-null  float64
#  15  CALC                            20758 non-null  int64
#  16  MTRANS                          20758 non-null  int64
# dtypes: float64(8), int64(9)
# memory usage: 2.7 MB
# None

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(train_x, train_y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

#표준화 작업 수
ss = StandardScaler()
ss.fit(train_x)
train_scaled = ss.transform(train_x)
test_scaled = ss.transform(test_x)
submit_scaled = ss.transform(submit_x)

# %% [raw]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(C=20, max_iter=10000) #max_iter: 모델 학습 시 최대 반복 횟수, C: 규제 강도(작을수록 규제 강함)
lr.fit(train_scaled, train_y)

print(f"train accuracy: {lr.score(train_scaled, train_y)}")#train data accuracy 측정
print(f"test accuracy: {lr.score(test_scaled, test_y)}") #test data accuracy 측정
# Out:
# train accuracy: 0.8635020554984584
# test accuracy: 0.8658959537572254

# %%
lr.predict(test_scaled)
# Out:
# array(['Obesity_Type_III', 'Overweight_Level_I', 'Obesity_Type_I', ...,
#        'Overweight_Level_I', 'Overweight_Level_II', 'Overweight_Level_II'],
#       dtype=object)

# %%
submit_x
# Out:
#           id  Gender        Age    Height      Weight  \
# 0      20758       1  26.899886  1.848294  120.644178
# 1      20759       0  21.000000  1.600000   66.000000
# 2      20760       0  26.000000  1.643355  111.600553
# 3      20761       1  20.979254  1.553127  103.669116
# 4      20762       0  26.000000  1.627396  104.835346
# ...      ...     ...        ...       ...         ...
# 13835  34593       1  23.327836  1.721384   78.030383
# 13836  34594       0  29.000000  1.590000   62.000000
# 13837  34595       0  22.935612  1.585547   44.376637
# 13838  34596       1  21.000000  1.620000   53.000000
# 13839  34597       1  26.490926  1.812259  120.980508
#
#        family_history_with_overweight  FAVC      FCVC       NCP  CAEC  SMOKE  \
# 0                                   1     1  2.938616  3.000000     2      0
# 1                                   1     1  2.000000  1.000000     2      0
# 2                                   1     1  3.000000  3.000000     2      0
# 3                                   1     1  2.000000  2.977909     2      0
# 4                                   1     1  3.000000  3.000000     2      0
# ...                               ...   ...       ...       ...   ...    ...
# 13835                               1     0  2.813234  3.000000     2      0
# 13836                               0     1  3.000000  3.000000     2      0
# 13837                               0     1  3.000000  2.273740     1      0
# 13838                               1     1  2.000000  3.000000     2      0
# 13839                               1     1  2.744994  3.000000     2      0
#
#            CH2O  SCC       FAF       TUE  CALC  MTRANS
# 0      2.825629    0  0.855400  0.000000     2       3
# 1      3.000000    0  1.000000  0.000000     2       3
# 2      2.621877    0  0.000000  0.250502     2       3
# 3      2.786417    0  0.094851  0.000000     2       3
# 4      2.653531    0  0.000000  0.741069     2       3
# ...         ...  ...       ...       ...   ...     ...
# 13835  1.000000    0  0.807076  0.778632     2       3
# 13836  2.000000    0  0.000000  0.000000     2       3
# 13837  2.000000    0  1.949840  1.000000     2       3
# 13838  2.000000    0  3.000000  2.000000     3       3
# 13839  2.205977    0  1.304291  0.630866     2       3
#
# [13840 rows x 17 columns]

# %%
submit_predict = lr.predict(submit_scaled)
submit_predict
# Out:
# array(['Obesity_Type_II', 'Overweight_Level_I', 'Obesity_Type_III', ...,
#        'Insufficient_Weight', 'Normal_Weight', 'Obesity_Type_II'],
#       dtype=object)

# %%
submit_data = {}
submit_data["id"] = [i+20758 for i in range(len(submit_predict))]
submit_data["NObeyesdad"] = submit_predict

# %%
import csv

# Write submit_data to a CSV file
with open("./submit_logistic.csv", "w", newline='') as file:
    writer = csv.DictWriter(file, fieldnames=submit_data.keys())
    writer.writeheader()
    # Convert submit_data to list of dictionaries and write rows
    for i in range(len(submit_predict)):
        row = {key: value[i] for key, value in submit_data.items()}
        writer.writerow(row)

# %%
a = pd.read_csv("./submit_logistic.csv")
a
# Out:
#           id           NObeyesdad
# 0      20758      Obesity_Type_II
# 1      20759   Overweight_Level_I
# 2      20760     Obesity_Type_III
# 3      20761       Obesity_Type_I
# 4      20762     Obesity_Type_III
# ...      ...                  ...
# 13835  34593  Overweight_Level_II
# 13836  34594        Normal_Weight
# 13837  34595  Insufficient_Weight
# 13838  34596        Normal_Weight
# 13839  34597      Obesity_Type_II
#
# [13840 rows x 2 columns]

# %% [raw]
# Neural Network

# %%
train_y.shape
# Out:
# (15568,)

# %%
train_scaled.shape
# Out:
# (15568, 17)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

input_dim = train_scaled.shape[1]

#클래스의 수
output_dim = len(np.unique(train_y))

model = Sequential([
    Dense(128, activation='relu', input_shape=(input_dim,)),
#    Dense(64, activation='relu'),
    Dense(output_dim, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#compile
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.utils import to_categorical

# 문자열 레이블을 정수로 인코딩
label_encoder = LabelEncoder()
train_y_encoded = label_encoder.fit_transform(train_y)

# 고유 클래스 수 확인
num_classes = len(np.unique(train_y_encoded))
print(f"Number of classes: {num_classes}")

# 레이블 데이터의 원-핫 인코딩
train_y_one_hot = to_categorical(train_y_encoded, num_classes)
print(f"Shape of one-hot encoded labels: {train_y_one_hot.shape}")
# Out:
# Number of classes: 7
# Shape of one-hot encoded labels: (15568, 7)

# %%
history = model.fit(train_scaled, train_y_one_hot, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.8862 - loss: 0.3336 - val_accuracy: 0.8671 - val_loss: 0.3553
# Epoch 2/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - accuracy: 0.8840 - loss: 0.3301 - val_accuracy: 0.8709 - val_loss: 0.3500
# Epoch 3/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - accuracy: 0.8813 - loss: 0.3400 - val_accuracy: 0.8693 - val_loss: 0.3570
# Epoch 4/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.8889 - loss: 0.3202 - val_accuracy: 0.8661 - val_loss: 0.3535
# Epoch 5/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - accuracy: 0.8831 - loss: 0.3331 - val_accuracy: 0.8645 - val_loss: 0.3533
# Epoch 6/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.8897 - loss: 0.3237 - val_accuracy: 0.8699 - val_loss: 0.3487
# Epoch 7/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.8866 - loss: 0.3240 - val_accuracy: 0.8703 - val_loss: 0.3489
# Epoch 8/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.8866 - loss: 0.3253 - val_accuracy: 0.8683 - val_loss: 0.3446
# Epoch 9/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.8953 - loss: 0.3087 - val_accuracy: 0.8693 - val_loss: 0.3451
# Epoch 10/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.8908 - loss: 0.3127 - val_accuracy: 0.8667 - val_loss: 0.3488
# Epoch 11/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.8912 - loss: 0.3250 - val_accuracy: 0.8671 - val_loss: 0.3498
# Epoch 12/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.8956 - loss: 0.3172 - val_accuracy: 0.8687 - val_loss: 0.3470
# Epoch 13/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.8925 - loss: 0.3157 - val_accuracy: 0.8667 - val_loss: 0.3521
# Epoch 14/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 0.8890 - loss: 0.3169 - val_accuracy: 0.8696 - val_loss: 0.3479
# Epoch 15/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.8989 - loss: 0.3008 - val_accuracy: 0.8732 - val_loss: 0.3473
# Epoch 16/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.8967 - loss: 0.3082 - val_accuracy: 0.8715 - val_loss: 0.3535
# Epoch 17/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.8983 - loss: 0.2913 - val_accuracy: 0.8715 - val_loss: 0.3517
# Epoch 18/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.8940 - loss: 0.3204 - val_accuracy: 0.8683 - val_loss: 0.3543
# Epoch 19/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.8962 - loss: 0.3074 - val_accuracy: 0.8706 - val_loss: 0.3519
# Epoch 20/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.8991 - loss: 0.2973 - val_accuracy: 0.8680 - val_loss: 0.3483
# Epoch 21/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.8985 - loss: 0.2922 - val_accuracy: 0.8687 - val_loss: 0.3559
# Epoch 22/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.9021 - loss: 0.2976 - val_accuracy: 0.8671 - val_loss: 0.3550
# Epoch 23/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.8989 - loss: 0.3029 - val_accuracy: 0.8732 - val_loss: 0.3536
# Epoch 24/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.8988 - loss: 0.2913 - val_accuracy: 0.8703 - val_loss: 0.3538
# Epoch 25/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.9019 - loss: 0.2962 - val_accuracy: 0.8703 - val_loss: 0.3548
# Epoch 26/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.9027 - loss: 0.2847 - val_accuracy: 0.8683 - val_loss: 0.3548
# Epoch 27/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.9008 - loss: 0.2965 - val_accuracy: 0.8706 - val_loss: 0.3576
# Epoch 28/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.9032 - loss: 0.2904 - val_accuracy: 0.8699 - val_loss: 0.3577
# Epoch 29/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.8989 - loss: 0.2924 - val_accuracy: 0.8693 - val_loss: 0.3535
# Epoch 30/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.9046 - loss: 0.2824 - val_accuracy: 0.8661 - val_loss: 0.3610
# Epoch 31/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.9012 - loss: 0.2850 - val_accuracy: 0.8687 - val_loss: 0.3579
# Epoch 32/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.9069 - loss: 0.2698 - val_accuracy: 0.8712 - val_loss: 0.3636
# Epoch 33/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - accuracy: 0.9050 - loss: 0.2925 - val_accuracy: 0.8677 - val_loss: 0.3604
# Epoch 34/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - accuracy: 0.9059 - loss: 0.2768 - val_accuracy: 0.8722 - val_loss: 0.3584
# Epoch 35/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.9023 - loss: 0.2868 - val_accuracy: 0.8696 - val_loss: 0.3555
# Epoch 36/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.9040 - loss: 0.2772 - val_accuracy: 0.8706 - val_loss: 0.3557
# Epoch 37/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.9039 - loss: 0.2890 - val_accuracy: 0.8651 - val_loss: 0.3596
# Epoch 38/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.8993 - loss: 0.2915 - val_accuracy: 0.8699 - val_loss: 0.3618
# Epoch 39/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.9015 - loss: 0.2810 - val_accuracy: 0.8699 - val_loss: 0.3614
# Epoch 40/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.9068 - loss: 0.2755 - val_accuracy: 0.8687 - val_loss: 0.3601
# Epoch 41/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.9069 - loss: 0.2690 - val_accuracy: 0.8683 - val_loss: 0.3633
# Epoch 42/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.9091 - loss: 0.2665 - val_accuracy: 0.8699 - val_loss: 0.3673
# Epoch 43/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.9108 - loss: 0.2641 - val_accuracy: 0.8712 - val_loss: 0.3653
# Epoch 44/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.9100 - loss: 0.2714 - val_accuracy: 0.8616 - val_loss: 0.3775
# Epoch 45/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.8989 - loss: 0.2815 - val_accuracy: 0.8748 - val_loss: 0.3642
# Epoch 46/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.9062 - loss: 0.2694 - val_accuracy: 0.8648 - val_loss: 0.3666
# Epoch 47/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.9021 - loss: 0.2773 - val_accuracy: 0.8664 - val_loss: 0.3691
# Epoch 48/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.9108 - loss: 0.2745 - val_accuracy: 0.8703 - val_loss: 0.3684
# Epoch 49/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.9145 - loss: 0.2635 - val_accuracy: 0.8696 - val_loss: 0.3688
# Epoch 50/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.9078 - loss: 0.2712 - val_accuracy: 0.8722 - val_loss: 0.3662

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %%
# 예측 수행
predictions = model.predict(train_scaled)
print(predictions)

# 각 샘플에 대해 가장 높은 확률을 가진 클래스 선택
predicted_classes = np.argmax(predictions, axis=1)
print(predicted_classes)

classes = np.unique(train_y)
result = classes[predicted_classes]
# Out:
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step
# [[1.5285927e-06 7.8439254e-01 5.5103072e-05 ... 4.8763013e-05
#   2.0023006e-01 1.5272123e-02]
#  [2.0424505e-03 1.2554530e-04 1.3134593e-02 ... 8.1827794e-14
#   3.9867770e-02 9.4461954e-01]
#  [4.2308432e-10 1.6944514e-05 9.0244192e-01 ... 2.7447322e-09
#   1.3094549e-02 8.4291317e-02]
#  ...
#  [2.2939075e-06 3.4166873e-01 4.3539869e-05 ... 8.1784384e-07
#   6.5580314e-01 2.4815230e-03]
#  [2.0810320e-14 2.2675419e-18 3.0912191e-04 ... 9.9968994e-01
#   1.2822126e-08 3.4360670e-07]
#  [3.9767039e-07 8.6575455e-11 9.5849603e-01 ... 7.3182275e-07
#   2.4746152e-04 3.8256580e-03]]
# [1 6 2 ... 5 4 2]

# %%
score = 0
for i in range(len(train_y)):
    if list(train_y)[i] == result[i]:
        score += 1
        
train_accuracy = score / len(train_y)

# %%
# 예측 수행
predictions = model.predict(test_scaled)
print(predictions)

# 각 샘플에 대해 가장 높은 확률을 가진 클래스 선택
predicted_classes = np.argmax(predictions, axis=1)
print(predicted_classes)

classes = np.unique(train_y)
result = classes[predicted_classes]
# Out:
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step
# [[4.0397717e-16 1.5514615e-19 2.2832262e-05 ... 9.9997127e-01
#   3.6182701e-10 5.8340262e-09]
#  [2.4913124e-06 1.5244547e-01 3.3076922e-03 ... 5.0197207e-07
#   6.4728254e-01 1.9696140e-01]
#  [2.0151676e-06 4.5132743e-05 7.7149254e-01 ... 8.1218564e-04
#   3.9774705e-02 1.8787257e-01]
#  ...
#  [4.6827109e-03 2.9242227e-03 5.9310379e-03 ... 1.1910115e-05
#   5.1765138e-01 4.6838680e-01]
#  [2.4327701e-07 1.6668253e-03 5.6555443e-03 ... 1.9220726e-08
#   2.0488769e-02 9.7218442e-01]
#  [5.2609625e-03 1.4870017e-04 8.2090609e-02 ... 8.3818651e-07
#   2.6839393e-01 6.3851798e-01]]
# [4 5 2 ... 5 6 6]

# %%
score = 0
for i in range(len(test_y)):
    if list(test_y)[i] == result[i]:
        score += 1
        
test_accuracy = score / len(test_y)

# %%
print(f"train accuracy: {train_accuracy}" )
print(f"test accuracy: {test_accuracy}" )
# Out:
# train accuracy: 0.905511305241521
# test accuracy: 0.8685934489402698
